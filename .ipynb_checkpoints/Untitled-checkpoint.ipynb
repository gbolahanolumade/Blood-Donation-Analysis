# %% [markdown]
# BLOOD DONATION ANALYSIS
#
# Models implemented:
#
#     Logistic Regression
#     Suport Vector Machine
#     Random Forest
#     Decision Tree
#     MLP Classifier

# %%
#importing libraries for reading, writing and performing basic operations
import  pandas as pd
import  numpy as np

#importing libraries for visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#importing libraries for splitting  and scoring
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score

# %%
#filter the unwanted warning
import warnings
warnings.simplefilter("ignore")

# %%
#importing all the required model for model comparison
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier

from sklearn.neural_network import MLPClassifier

from sklearn.svm import SVC

# %%
#importing data
train = pd.read_csv("blood-train.csv")
test = pd.read_csv("blood-test.csv")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   200 non-null    int64
#  1   Months since Last Donation   200 non-null    int64
#  2   Number of Donations          200 non-null    int64
#  3   Total Volume Donated (c.c.)  200 non-null    int64
#  4   Months since First Donation  200 non-null    int64
# dtypes: int64(5)
# memory usage: 7.9 KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   576 non-null    int64
#  1   Months since Last Donation   576 non-null    int64
#  2   Number of Donations          576 non-null    int64
#  3   Total Volume Donated (c.c.)  576 non-null    int64
#  4   Months since First Donation  576 non-null    int64
#  5   Made Donation in March 2007  576 non-null    int64
# dtypes: int64(6)
# memory usage: 27.1 KB

# %%
print("test shape :", test.shape)
print("train shape :", train.shape)
# Out:
# test shape : (200, 5)
# train shape : (576, 6)

# %%
train.head()
# Out:
#    Unnamed: 0  Months since Last Donation  Number of Donations  \
# 0         619                           2                   50
# 1         664                           0                   13
# 2         441                           1                   16
# 3         160                           2                   20
# 4         358                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#    Made Donation in March 2007
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            0

# %%
Y = train.iloc[:,-1]

# %%
train["Made Donation in March 2007"].value_counts()
# Out:
# 0    438
# 1    138
# Name: Made Donation in March 2007, dtype: int64

# %%
#removing Unamed train data
old_train = train
train = train.iloc[:,1:5]

# %%
old_test = test
test = test.iloc[:, 1:]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Months since Last Donation   576 non-null    int64
#  1   Number of Donations          576 non-null    int64
#  2   Total Volume Donated (c.c.)  576 non-null    int64
#  3   Months since First Donation  576 non-null    int64
# dtypes: int64(4)
# memory usage: 18.1 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Months since Last Donation   200 non-null    int64
#  1   Number of Donations          200 non-null    int64
#  2   Total Volume Donated (c.c.)  200 non-null    int64
#  3   Months since First Donation  200 non-null    int64
# dtypes: int64(4)
# memory usage: 6.4 KB

# %%
#merging both train and test data
df=pd.merge(train,test)

# %%
df.head()
# Out:
#    Months since Last Donation  Number of Donations  \
# 0                           2                    2
# 1                           2                    2
# 2                           2                    2
# 3                           2                    2
# 4                           2                    2
#
#    Total Volume Donated (c.c.)  Months since First Donation
# 0                          500                            4
# 1                          500                            4
# 2                          500                            4
# 3                          500                            4
# 4                          500                            4

# %%
#setting the independent variable
X= df.iloc[:,:]
X.head()
# Out:
#    Months since Last Donation  Number of Donations  \
# 0                           2                    2
# 1                           2                    2
# 2                           2                    2
# 3                           2                    2
# 4                           2                    2
#
#    Total Volume Donated (c.c.)  Months since First Donation
# 0                          500                            4
# 1                          500                            4
# 2                          500                            4
# 3                          500                            4
# 4                          500                            4

# %% [markdown]
# DATA EXPLORATION

# %%
train.describe()
# Out:
#        Months since Last Donation  Number of Donations  \
# count                  576.000000           576.000000
# mean                     9.439236             5.427083
# std                      8.175454             5.740010
# min                      0.000000             1.000000
# 25%                      2.000000             2.000000
# 50%                      7.000000             4.000000
# 75%                     14.000000             7.000000
# max                     74.000000            50.000000
#
#        Total Volume Donated (c.c.)  Months since First Donation
# count                   576.000000                   576.000000
# mean                   1356.770833                    34.050347
# std                    1435.002556                    24.227672
# min                     250.000000                     2.000000
# 25%                     500.000000                    16.000000
# 50%                    1000.000000                    28.000000
# 75%                    1750.000000                    49.250000
# max                   12500.000000                    98.000000

# %%
#boxplot for month since last donation
plt.figure(figsize=(20,10))
sns.boxplot(y="Months since Last Donation", data=old_train)
# Out:
# <AxesSubplot:ylabel='Months since Last Donation'>

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Made Donation in March 2007, dtype: int64

# %%
#correlation between all variables
corrmat=X.corr()
f, ax = plt.subplots(figsize=(9,8))
sns.heatmap(corrmat, ax = ax, cmap="YlGnBu", linewidth=0.1,fmt= ".2f", annot=True)
# Out:
# <AxesSubplot:>

# %%
#Printing all unique value for Month Since Last donation
train["Months since Last Donation"].unique()
# Out:
# array([ 2,  0,  1,  4,  5,  3, 12,  6, 11,  9, 10, 13, 14,  8,  7, 16, 23,
#        21, 18, 22, 26, 35, 74, 15, 20, 17, 25, 39, 72], dtype=int64)
